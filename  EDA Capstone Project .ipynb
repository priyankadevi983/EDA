# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers = pd.read_csv('olist_customers_dataset.csv')
geolocation = pd.read_csv('olist_geolocation_dataset.csv')
order_items = pd.read_csv('olist_order_items_dataset.csv')
order_payments = pd.read_csv('olist_order_payments_dataset.csv')
order_reviews = pd.read_csv('olist_order_reviews_dataset.csv') # null value exist 
orders= pd.read_csv('olist_orders_dataset.csv') # null value exist 
products = pd.read_csv('olist_products_dataset.csv') # null value exist 
sellers = pd.read_csv('olist_sellers_dataset.csv')
product_category_name_translation = pd.read_csv('product_category_name_translation.csv')

# %%
df1=pd.DataFrame(orders )  
df2=pd.DataFrame(order_payments)
df3 =pd.DataFrame(order_items)
df4 = pd.DataFrame(order_reviews)
df5 = pd.DataFrame(customers)
df6 = pd.DataFrame(products)
df7 = pd.DataFrame(geolocation)
df8 = pd.DataFrame(sellers)

# %%
df9 =pd.merge(df1,df2,on = 'order_id')
df10 =pd.merge(df3,df4,on = 'order_id')
df11 =pd.merge(df9,df10,on = 'order_id')
df12 =pd.merge(df1,df5,on = 'customer_id')
df13 =pd.merge(df11,df12,on = 'customer_id')
df14=pd.merge(df13,df6,on = 'product_id')
df15=pd.merge(df14,df8,on = 'seller_id')

# %%
df15.head(5)
# Out:
#                          order_id_x                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4  0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
#
#   order_status_x order_purchase_timestamp_x  order_approved_at_x  \
# 0      delivered        2017-10-02 10:56:33  2017-10-02 11:07:15
# 1      delivered        2017-10-02 10:56:33  2017-10-02 11:07:15
# 2      delivered        2017-10-02 10:56:33  2017-10-02 11:07:15
# 3      delivered        2017-08-15 18:29:31  2017-08-15 20:05:16
# 4      delivered        2017-08-02 18:24:47  2017-08-02 18:43:15
#
#   order_delivered_carrier_date_x order_delivered_customer_date_x  \
# 0            2017-10-04 19:55:00             2017-10-10 21:25:13
# 1            2017-10-04 19:55:00             2017-10-10 21:25:13
# 2            2017-10-04 19:55:00             2017-10-10 21:25:13
# 3            2017-08-17 15:28:33             2017-08-18 14:44:43
# 4            2017-08-04 17:35:43             2017-08-07 18:30:01
#
#   order_estimated_delivery_date_x  payment_sequential payment_type  ...  \
# 0             2017-10-18 00:00:00                   1  credit_card  ...
# 1             2017-10-18 00:00:00                   3      voucher  ...
# 2             2017-10-18 00:00:00                   2      voucher  ...
# 3             2017-08-28 00:00:00                   1  credit_card  ...
# 4             2017-08-15 00:00:00                   1  credit_card  ...
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       268.0                 4.0
# 1                 40.0                       268.0                 4.0
# 2                 40.0                       268.0                 4.0
# 3                 40.0                       268.0                 4.0
# 4                 40.0                       268.0                 4.0
#
#   product_weight_g product_length_cm product_height_cm  product_width_cm  \
# 0            500.0              19.0               8.0              13.0
# 1            500.0              19.0               8.0              13.0
# 2            500.0              19.0               8.0              13.0
# 3            500.0              19.0               8.0              13.0
# 4            500.0              19.0               8.0              13.0
#
#    seller_zip_code_prefix seller_city  seller_state
# 0                    9350        maua            SP
# 1                    9350        maua            SP
# 2                    9350        maua            SP
# 3                    9350        maua            SP
# 4                    9350        maua            SP
#
# [5 rows x 46 columns]

# %%
df15['product_category_name'].nunique()
# Out:
# 73

# %%
df15.isnull().sum()
# Out:
# order_id_x                              0
# customer_id                             0
# order_status_x                          0
# order_purchase_timestamp_x              0
# order_approved_at_x                    15
# order_delivered_carrier_date_x       1254
# order_delivered_customer_date_x      2588
# order_estimated_delivery_date_x         0
# payment_sequential                      0
# payment_type                            0
# payment_installments                    0
# payment_value                           0
# order_item_id                           0
# product_id                              0
# seller_id                               0
# shipping_limit_date                     0
# price                                   0
# freight_value                           0
# review_id                               0
# review_score                            0
# review_comment_title               104226
# review_comment_message              67650
# review_creation_date                    0
# review_answer_timestamp                 0
# order_id_y                              0
# order_status_y                          0
# order_purchase_timestamp_y              0
# order_approved_at_y                    15
# order_delivered_carrier_date_y       1254
# order_delivered_customer_date_y      2588
# order_estimated_delivery_date_y         0
# customer_unique_id                      0
# customer_zip_code_prefix                0
# customer_city                           0
# customer_state                          0
# product_category_name                1709
# product_name_lenght                  1709
# product_description_lenght           1709
# product_photos_qty                   1709
# product_weight_g                       20
# product_length_cm                      20
# product_height_cm                      20
# product_width_cm                       20
# seller_zip_code_prefix                  0
# seller_city                             0
# seller_state                            0
# dtype: int64

# %%
df15= df15.dropna()

# %%
df15.isnull().sum()
# Out:
# order_id_x                         0
# customer_id                        0
# order_status_x                     0
# order_purchase_timestamp_x         0
# order_approved_at_x                0
# order_delivered_carrier_date_x     0
# order_delivered_customer_date_x    0
# order_estimated_delivery_date_x    0
# payment_sequential                 0
# payment_type                       0
# payment_installments               0
# payment_value                      0
# order_item_id                      0
# product_id                         0
# seller_id                          0
# shipping_limit_date                0
# price                              0
# freight_value                      0
# review_id                          0
# review_score                       0
# review_comment_title               0
# review_comment_message             0
# review_creation_date               0
# review_answer_timestamp            0
# order_id_y                         0
# order_status_y                     0
# order_purchase_timestamp_y         0
# order_approved_at_y                0
# order_delivered_carrier_date_y     0
# order_delivered_customer_date_y    0
# order_estimated_delivery_date_y    0
# customer_unique_id                 0
# customer_zip_code_prefix           0
# customer_city                      0
# customer_state                     0
# product_category_name              0
# product_name_lenght                0
# product_description_lenght         0
# product_photos_qty                 0
# product_weight_g                   0
# product_length_cm                  0
# product_height_cm                  0
# product_width_cm                   0
# seller_zip_code_prefix             0
# seller_city                        0
# seller_state                       0
# dtype: int64

# %%
df15.duplicated().sum()
# Out:
# 0

# %%
df15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11751 entries, 58 to 118300
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   order_id_x                       11751 non-null  object
#  1   customer_id                      11751 non-null  object
#  2   order_status_x                   11751 non-null  object
#  3   order_purchase_timestamp_x       11751 non-null  object
#  4   order_approved_at_x              11751 non-null  object
#  5   order_delivered_carrier_date_x   11751 non-null  object
#  6   order_delivered_customer_date_x  11751 non-null  object
#  7   order_estimated_delivery_date_x  11751 non-null  object
#  8   payment_sequential               11751 non-null  int64
#  9   payment_type                     11751 non-null  object
#  10  payment_installments             11751 non-null  int64
#  11  payment_value                    11751 non-null  float64
#  12  order_item_id                    11751 non-null  int64
#  13  product_id                       11751 non-null  object
#  14  seller_id                        11751 non-null  object
#  15  shipping_limit_date              11751 non-null  object
#  16  price                            11751 non-null  float64
#  17  freight_value                    11751 non-null  float64
#  18  review_id                        11751 non-null  object
#  19  review_score                     11751 non-null  int64
#  20  review_comment_title             11751 non-null  object
#  21  review_comment_message           11751 non-null  object
#  22  review_creation_date             11751 non-null  object
#  23  review_answer_timestamp          11751 non-null  object
#  24  order_id_y                       11751 non-null  object
#  25  order_status_y                   11751 non-null  object
#  26  order_purchase_timestamp_y       11751 non-null  object
#  27  order_approved_at_y              11751 non-null  object
#  28  order_delivered_carrier_date_y   11751 non-null  object
#  29  order_delivered_customer_date_y  11751 non-null  object
#  30  order_estimated_delivery_date_y  11751 non-null  object
#  31  customer_unique_id               11751 non-null  object
#  32  customer_zip_code_prefix         11751 non-null  int64
#  33  customer_city                    11751 non-null  object
#  34  customer_state                   11751 non-null  object
#  35  product_category_name            11751 non-null  object
#  36  product_name_lenght              11751 non-null  float64
#  37  product_description_lenght       11751 non-null  float64
#  38  product_photos_qty               11751 non-null  float64
#  39  product_weight_g                 11751 non-null  float64
#  40  product_length_cm                11751 non-null  float64
#  41  product_height_cm                11751 non-null  float64
#  42  product_width_cm                 11751 non-null  float64
#  43  seller_zip_code_prefix           11751 non-null  int64
#  44  seller_city                      11751 non-null  object
#  45  seller_state                     11751 non-null  object
# dtypes: float64(10), int64(6), object(30)
# memory usage: 4.2+ MB

# %%
df15.describe()
# Out:
#        payment_sequential  payment_installments  payment_value  order_item_id  \
# count        11751.000000          11751.000000   11751.000000   11751.000000
# mean             1.057272              3.059654     198.151126       1.252404
# std              0.378402              2.838207     308.630532       0.778726
# min              1.000000              1.000000       0.050000       1.000000
# 25%              1.000000              1.000000      67.440000       1.000000
# 50%              1.000000              2.000000     122.690000       1.000000
# 75%              1.000000              4.000000     209.780000       1.000000
# max             12.000000             20.000000    7274.880000      13.000000
#
#               price  freight_value  review_score  customer_zip_code_prefix  \
# count  11751.000000   11751.000000  11751.000000              11751.000000
# mean     130.965543      21.993697      3.769126              33865.726321
# std      219.259830      18.772834      1.576223              28979.700727
# min        0.850000       0.000000      1.000000               1003.000000
# 25%       40.000000      12.915000      3.000000              11020.000000
# 50%       78.900000      18.230000      5.000000              23560.000000
# 75%      139.000000      23.345000      5.000000              55305.000000
# max     6729.000000     375.280000      5.000000              99980.000000
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         11751.000000                11751.000000        11751.000000
# mean             49.292571                  814.670581            2.203472
# std               9.747913                  644.853363            1.695865
# min               8.000000                    4.000000            1.000000
# 25%              43.000000                  366.000000            1.000000
# 50%              52.000000                  634.000000            1.000000
# 75%              57.000000                 1031.000000            3.000000
# max              64.000000                 3985.000000           17.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      11751.000000        11751.00000       11751.000000
# mean        2116.237852           28.96528          16.569483
# std         3753.872665           15.27857          13.184372
# min            0.000000           11.00000           2.000000
# 25%          292.000000           18.00000           8.000000
# 50%          650.000000           23.00000          13.000000
# 75%         1764.500000           35.00000          20.000000
# max        30000.000000          105.00000         105.000000
#
#        product_width_cm  seller_zip_code_prefix
# count      11751.000000            11751.000000
# mean          22.459365            23412.347375
# std           10.995838            26974.623340
# min            7.000000             1001.000000
# 25%           15.000000             5849.000000
# 50%           20.000000            13405.000000
# 75%           29.000000            24451.000000
# max          105.000000            99730.000000

# %%
df15.corr()
# Out:
# C:\Users\91704\AppData\Local\Temp\ipykernel_129088\3792209451.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df15.corr()
#                             payment_sequential  payment_installments  \
# payment_sequential                    1.000000             -0.096848
# payment_installments                 -0.096848              1.000000
# payment_value                        -0.062735              0.299445
# order_item_id                        -0.029421              0.071894
# price                                 0.030863              0.285931
# freight_value                         0.032303              0.206856
# review_score                          0.006332             -0.044747
# customer_zip_code_prefix              0.023469              0.074722
# product_name_lenght                   0.034334             -0.006589
# product_description_lenght           -0.002134              0.028758
# product_photos_qty                    0.020698              0.003083
# product_weight_g                      0.039394              0.182883
# product_length_cm                     0.042975              0.116998
# product_height_cm                     0.031179              0.131362
# product_width_cm                      0.069418              0.123447
# seller_zip_code_prefix               -0.012187              0.065634
#
#                             payment_value  order_item_id     price  \
# payment_sequential              -0.062735      -0.029421  0.030863
# payment_installments             0.299445       0.071894  0.285931
# payment_value                    1.000000       0.229237  0.759545
# order_item_id                    0.229237       1.000000 -0.070363
# price                            0.759545      -0.070363  1.000000
# freight_value                    0.385819      -0.050809  0.424536
# review_score                    -0.105944      -0.157964 -0.017856
# customer_zip_code_prefix         0.093075       0.017115  0.069972
# product_name_lenght             -0.002371      -0.014169  0.016799
# product_description_lenght       0.171892      -0.026038  0.191279
# product_photos_qty               0.019198      -0.063703  0.063529
# product_weight_g                 0.328983       0.021670  0.319663
# product_length_cm                0.190341       0.007425  0.181378
# product_height_cm                0.222107       0.072100  0.192859
# product_width_cm                 0.167578       0.008871  0.168746
# seller_zip_code_prefix           0.081759      -0.035254  0.099320
#
#                             freight_value  review_score  \
# payment_sequential               0.032303      0.006332
# payment_installments             0.206856     -0.044747
# payment_value                    0.385819     -0.105944
# order_item_id                   -0.050809     -0.157964
# price                            0.424536     -0.017856
# freight_value                    1.000000     -0.030374
# review_score                    -0.030374      1.000000
# customer_zip_code_prefix         0.265075     -0.021658
# product_name_lenght              0.040768     -0.006587
# product_description_lenght       0.131111      0.000289
# product_photos_qty               0.029657      0.025217
# product_weight_g                 0.593197     -0.043278
# product_length_cm                0.380547     -0.012500
# product_height_cm                0.364430     -0.053284
# product_width_cm                 0.352866     -0.006107
# seller_zip_code_prefix           0.185396      0.009698
#
#                             customer_zip_code_prefix  product_name_lenght  \
# payment_sequential                          0.023469             0.034334
# payment_installments                        0.074722            -0.006589
# payment_value                               0.093075            -0.002371
# order_item_id                               0.017115            -0.014169
# price                                       0.069972             0.016799
# freight_value                               0.265075             0.040768
# review_score                               -0.021658            -0.006587
# customer_zip_code_prefix                    1.000000             0.025309
# product_name_lenght                         0.025309             1.000000
# product_description_lenght                  0.033894             0.111258
# product_photos_qty                          0.019782             0.190307
# product_weight_g                            0.004400             0.019185
# product_length_cm                           0.010760             0.036288
# product_height_cm                           0.019358            -0.042619
# product_width_cm                           -0.012805             0.031504
# seller_zip_code_prefix                      0.094747             0.000800
#
#                             product_description_lenght  product_photos_qty  \
# payment_sequential                           -0.002134            0.020698
# payment_installments                          0.028758            0.003083
# payment_value                                 0.171892            0.019198
# order_item_id                                -0.026038           -0.063703
# price                                         0.191279            0.063529
# freight_value                                 0.131111            0.029657
# review_score                                  0.000289            0.025217
# customer_zip_code_prefix                      0.033894            0.019782
# product_name_lenght                           0.111258            0.190307
# product_description_lenght                    1.000000            0.147823
# product_photos_qty                            0.147823            1.000000
# product_weight_g                              0.100909            0.015190
# product_length_cm                             0.078471            0.044014
# product_height_cm                             0.094141           -0.007078
# product_width_cm                             -0.032030           -0.014488
# seller_zip_code_prefix                        0.058099           -0.077148
#
#                             product_weight_g  product_length_cm  \
# payment_sequential                  0.039394           0.042975
# payment_installments                0.182883           0.116998
# payment_value                       0.328983           0.190341
# order_item_id                       0.021670           0.007425
# price                               0.319663           0.181378
# freight_value                       0.593197           0.380547
# review_score                       -0.043278          -0.012500
# customer_zip_code_prefix            0.004400           0.010760
# product_name_lenght                 0.019185           0.036288
# product_description_lenght          0.100909           0.078471
# product_photos_qty                  0.015190           0.044014
# product_weight_g                    1.000000           0.550591
# product_length_cm                   0.550591           1.000000
# product_height_cm                   0.599971           0.242492
# product_width_cm                    0.522814           0.597258
# seller_zip_code_prefix              0.017483           0.038723
#
#                             product_height_cm  product_width_cm  \
# payment_sequential                   0.031179          0.069418
# payment_installments                 0.131362          0.123447
# payment_value                        0.222107          0.167578
# order_item_id                        0.072100          0.008871
# price                                0.192859          0.168746
# freight_value                        0.364430          0.352866
# review_score                        -0.053284         -0.006107
# customer_zip_code_prefix             0.019358         -0.012805
# product_name_lenght                 -0.042619          0.031504
# product_description_lenght           0.094141         -0.032030
# product_photos_qty                  -0.007078         -0.014488
# product_weight_g                     0.599971          0.522814
# product_length_cm                    0.242492          0.597258
# product_height_cm                    1.000000          0.284443
# product_width_cm                     0.284443          1.000000
# seller_zip_code_prefix               0.010144         -0.002657
#
#                             seller_zip_code_prefix
# payment_sequential                       -0.012187
# payment_installments                      0.065634
# payment_value                             0.081759
# order_item_id                            -0.035254
# price                                     0.099320
# freight_value                             0.185396
# review_score                              0.009698
# customer_zip_code_prefix                  0.094747
# product_name_lenght                       0.000800
# product_description_lenght                0.058099
# product_photos_qty                       -0.077148
# product_weight_g                          0.017483
# product_length_cm                         0.038723
# product_height_cm                         0.010144
# product_width_cm                         -0.002657
# seller_zip_code_prefix                    1.000000

# %%
df15.shape
# Out:
# (11751, 46)

# %%
sns.set_theme(style = 'dark')
sns.countplot(x ='review_score',data =df15 )
plt.suptitle('Total Revew Score')
plt.show()
df15['review_score'].value_counts()/df15['review_score'].count()*100
# Out:
# 5    52.752957
# 1    19.130287
# 4    14.858310
# 3     8.067399
# 2     5.191048
# Name: review_score, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style = 'dark')
sns.countplot(x ='customer_state',data =df15 )
plt.suptitle('order by customer states')
plt.show()
total_states = df15['customer_state'].nunique()
total_customer =df15['customer_state'].value_counts().sum()
print('total_states',total_states)
print('total_custmer_by_states',total_customer)
total = df15['customer_state'].unique()
number_of_custmer =df15['customer_state'].value_counts()
total_custmer =df15['customer_state'].value_counts().sum()
percent = (number_of_custmer/total_custmer)*100
customer_by_state =pd.DataFrame({"number_of_custmer":number_of_custmer,
                                   'percentage':percent })
print(customer_by_state)
# Out:
# total_states 27
# total_custmer_by_states 11751
#     number_of_custmer  percentage
# SP               5111   43.494171
# RJ               1503   12.790401
# MG               1266   10.773551
# RS                520    4.425155
# PR                510    4.340056
# BA                464    3.948600
# SC                377    3.208238
# DF                258    2.195558
# ES                248    2.110459
# PE                235    1.999830
# GO                228    1.940260
# CE                168    1.429666
# PA                146    1.242447
# MT                135    1.148838
# MS                 94    0.799932
# PB                 79    0.672283
# RN                 78    0.663773
# PI                 68    0.578674
# MA                 67    0.570164
# SE                 50    0.425496
# AL                 46    0.391456
# TO                 38    0.323377
# RO                 21    0.178708
# AM                 20    0.170198
# AP                 10    0.085099
# RR                  7    0.059569
# AC                  4    0.034040

# %%
total = df15['customer_state'].unique()
number_of_custmer =df15['customer_state'].value_counts()
total_custmer =df15['customer_state'].value_counts().sum()
percent = (number_of_custmer/total_custmer)*100
customer_by_state =pd.DataFrame({"number_of_custmer":number_of_custmer,
                                   'percentage':percent })
print(customer_by_state)

plt.figure(figsize=(10,10))
sns.set_theme(style = 'dark')
sns.barplot(x = customer_by_state.index,y =customer_by_state.percentage)
plt.suptitle('%Customer By States')
plt.show()
total_states = df15['customer_state'].nunique()
print('total_states',total_states)
print('total_custmer_by_states',total_custmer)
# Out:
#     number_of_custmer  percentage
# SP               5111   43.494171
# RJ               1503   12.790401
# MG               1266   10.773551
# RS                520    4.425155
# PR                510    4.340056
# BA                464    3.948600
# SC                377    3.208238
# DF                258    2.195558
# ES                248    2.110459
# PE                235    1.999830
# GO                228    1.940260
# CE                168    1.429666
# PA                146    1.242447
# MT                135    1.148838
# MS                 94    0.799932
# PB                 79    0.672283
# RN                 78    0.663773
# PI                 68    0.578674
# MA                 67    0.570164
# SE                 50    0.425496
# AL                 46    0.391456
# TO                 38    0.323377
# RO                 21    0.178708
# AM                 20    0.170198
# AP                 10    0.085099
# RR                  7    0.059569
# AC                  4    0.034040
# total_states 27
# total_custmer_by_states 11751

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style = 'dark')
sns.barplot(x ='customer_state',y ='payment_value', data =df15 )
plt.suptitle(' Payment by customer states')
plt.show()

# %%
sns.set_theme(style = 'dark')
sns.barplot(x ='payment_value',y ='customer_unique_id',data =df15[:10] )
plt.suptitle('Top Customers')
plt.show()

# %%
number_of_order = df15['order_item_id'].value_counts()
total_number_of_order = number_of_order.sum()
percent =((number_of_order/total_number_of_order)*100)

# %%
df_items_per_order=pd.DataFrame({'Order in item':df15['order_item_id'].unique(),"Number of order":number_of_order,
                                   "percentage": percent })
print(df_items_per_order)
# Out:
#     Order in item  Number of order  percentage
# 1               1             9939   84.580036
# 2               2             1243   10.577823
# 3               3              296    2.518935
# 4               4              127    1.080759
# 5               5               71    0.604204
# 6               6               45    0.382946
# 7               7               10    0.085099
# 8               8                4    0.034040
# 9               9                4    0.034040
# 10             10                4    0.034040
# 11             11                4    0.034040
# 12             12                3    0.025530
# 13             13                1    0.008510

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style = 'dark')
sns.barplot(x = 'Order in item',y = 'percentage',data = df_items_per_order)
plt.suptitle('Number Of Order in item')
plt.show()
df_items_per_order['percentage']
# Out:
# 1     84.580036
# 2     10.577823
# 3      2.518935
# 4      1.080759
# 5      0.604204
# 6      0.382946
# 7      0.085099
# 8      0.034040
# 9      0.034040
# 10     0.034040
# 11     0.034040
# 12     0.025530
# 13     0.008510
# Name: percentage, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style = 'dark')
sns.barplot(x ='order_item_id',y ='payment_value', data =df15 )
plt.suptitle('Highest Payment by order_itemID')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style = 'dark')
sns.barplot(x ='customer_state',y ='order_item_id', data =df15 )
plt.suptitle('Order_Item_By_Customer_states')
plt.show()

# %%
sns.set_theme(style = 'dark')
sns.countplot(x ='order_status_x',data =df15 )
plt.suptitle('Total Sale')
plt.show()
total_sale = df15['order_status_x'].value_counts().sum()
print("Total Sales",total_sale)
# Out:
# Total Sales 11751

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style = 'dark')
sns.barplot(x ='payment_type',y ='payment_value', data =df15 )
plt.suptitle('Highest Payment by payment_type')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.set_theme(style = 'dark')
sns.barplot(x ='price',y ='product_category_name', data =df15 )
plt.suptitle('Price of product')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.set_theme(style = 'dark')
sns.barplot(x ='payment_value',y ='product_category_name', data =df15 )
plt.suptitle('payment of product_category_name')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style = 'dark')
sns.barplot(x ='order_item_id',y ='price', data =df15 )
plt.suptitle('Price by order_itemID')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.set_theme(style ='dark')
sns.countplot(x ='product_category_name',data =df15 )
plt.suptitle('higest sales product')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.set_theme(style = 'dark')
sns.countplot(y ='product_category_name',data =df15 )
plt.suptitle('higest sales product')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.set_theme(style = 'dark')
sns.countplot(y = 'product_category_name',data =df15 )
plt.suptitle('higest sales product by states')
plt.show()
